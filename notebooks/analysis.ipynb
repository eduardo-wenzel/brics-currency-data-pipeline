# %% [markdown]
# # BRICS Exchange Analysis
# Notebook inicial para analise exploratoria da serie historica de cambio.

# %%
query = '''
SELECT target_currency, reference_date, rate, loaded_at
FROM analytics.fact_exchange_rate_history
ORDER BY loaded_at DESC
LIMIT 100;
'''
print(query)
